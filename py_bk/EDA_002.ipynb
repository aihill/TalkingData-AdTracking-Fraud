# %%
import utils

# %%
train = utils.read_pickles('../data/train').sort_values('click_time')
label1 = train[train.is_attributed==1]
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]

# %%
def get_df():
    ip, app, device, os, channel, click_time, attributed_time, att = label1.sample(1).values[0]
    tmp = train[train.ip==ip]
    return tmp[tmp.app==app][tmp.device==device][tmp.os==os][tmp.channel==channel]

# %%
get_df()
# Out:
#              ip  app  device  os  channel          click_time attributed_time  \
# 76907      5348   10       1  13      377 2017-11-06 16:01:22             NaT
# 970578     5348   10       1  13      377 2017-11-06 16:21:10             NaT
# 2586806    5348   10       1  13      377 2017-11-06 17:10:14             NaT
# 3914911    5348   10       1  13      377 2017-11-06 18:24:20             NaT
# 4945867    5348   10       1  13      377 2017-11-06 20:20:12             NaT
# 5424963    5348   10       1  13      377 2017-11-06 21:27:14             NaT
# 6284441    5348   10       1  13      377 2017-11-06 22:34:13             NaT
# 6470657    5348   10       1  13      377 2017-11-06 22:42:28             NaT
# 6665871    5348   10       1  13      377 2017-11-06 22:50:17             NaT
# 7488664    5348   10       1  13      377 2017-11-06 23:16:37             NaT
# 8103944    5348   10       1  13      377 2017-11-06 23:33:02             NaT
# ...

# %%
get_df()
# Out:
#               ip  app  device  os  channel          click_time  \
# 62468138  201564   37       1  13       21 2017-11-07 17:16:47
#
#              attributed_time  is_attributed
# 62468138 2017-11-08 05:36:36              1

# %%
get_df()
# Out:
#                ip  app  device  os  channel          click_time  \
# 147021813  320074    5       1  37      113 2017-11-09 04:35:03
#
#               attributed_time  is_attributed
# 147021813 2017-11-09 04:35:36              1

# %%
get_df()
# Out:
#               ip  app  device  os  channel          click_time  \
# 8851585    93226   19       0   0      347 2017-11-06 23:50:23
# 29621818   93226   19       0   0      347 2017-11-07 06:04:09
# 61186665   93226   19       0   0      347 2017-11-07 16:34:13
# 65852324   93226   19       0   0      347 2017-11-07 22:27:51
# 98006377   93226   19       0   0      347 2017-11-08 08:58:29
# 100350141  93226   19       0   0      347 2017-11-08 09:45:07
# 112474422  93226   19       0   0      347 2017-11-08 13:17:04
# 112525725  93226   19       0   0      347 2017-11-08 13:17:54
# 138965882  93226   19       0   0      347 2017-11-09 02:13:18
# 138971227  93226   19       0   0      347 2017-11-09 02:13:25
# 138973788  93226   19       0   0      347 2017-11-09 02:13:27
# 139055319  93226   19       0   0      347 2017-11-09 02:15:01
# 143410643  93226   19       0   0      347 2017-11-09 03:38:35
# 148727248  93226   19       0   0      347 2017-11-09 04:59:46
# ...

# %%
get_df()
# Out:
#               ip  app  device  os  channel          click_time  \
# 151522247  54503   19       0  38      213 2017-11-09 05:45:10
#
#               attributed_time  is_attributed
# 151522247 2017-11-09 05:50:40              1

# %%
get_df()
# Out:
#              ip  app  device  os  channel          click_time  \
# 16887214  47552   35       1  17      274 2017-11-07 02:12:39
#
#              attributed_time  is_attributed
# 16887214 2017-11-07 02:28:37              1

# %%
get_df()
# Out:
#                ip  app  device  os  channel          click_time  \
# 65029199   142456   11       1  19      469 2017-11-07 21:15:23
# 136143829  142456   11       1  19      469 2017-11-09 01:17:47
# 151255724  142456   11       1  19      469 2017-11-09 05:40:37
# 157786702  142456   11       1  19      469 2017-11-09 07:31:18
# 166798192  142456   11       1  19      469 2017-11-09 10:33:32
#
#               attributed_time  is_attributed
# 65029199                  NaT              0
# 136143829 2017-11-09 01:52:37              1
# 151255724                 NaT              0
# 157786702                 NaT              0
# 166798192                 NaT              0
