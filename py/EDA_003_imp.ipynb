# %%
from matplotlib import pyplot as plt
import pandas as pd
import sys
sys.path.append('/home/kazuki_onodera/Python')
import xgbextension as ex

# %%
imp = pd.read_csv('LOG/imp_902_predict_319-1.py.csv')

# %%
ex.pltImp(imp)
