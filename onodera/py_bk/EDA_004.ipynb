# %%
import pandas as pd
import utils

# %%
# =============================================================================
# load train
# =============================================================================

train = pd.concat([utils.read_pickles('../data/train'),
                   pd.read_pickle('../data/102_train.p')], axis=1)
# Out:
# 100%|██████████| 10/10 [00:18<00:00,  1.81s/it]

# %%
train
# Out:
#                ip  app  device  os  channel          click_time  \
# 0               1    1       1   2      125 2017-11-09 14:34:10
# 1               1    1       1   9      125 2017-11-09 03:01:54
# 2               1    1       1  48       13 2017-11-09 10:42:11
# 3               1    2       1   2      477 2017-11-08 17:47:39
# 4               1    2       1   2      477 2017-11-08 20:08:39
# 5               1    2       1   2      477 2017-11-08 20:10:32
# 6               1    2       1   2      477 2017-11-08 22:03:35
# 7               1    2       1   2      477 2017-11-09 03:01:59
# 8               1    2       1   6      477 2017-11-08 19:59:36
# 9               1    2       1   9      477 2017-11-09 03:01:50
# 10              1    2       1  15      477 2017-11-08 17:25:31
# 11              1    2       1  48      477 2017-11-09 10:42:13
# 12              1    2       1  49      477 2017-11-08 20:05:42
# 13              1    2       1  52      477 2017-11-09 10:34:25
# ...

# %%
train.sort_values(['app', 'device', 'click_time'])
# Out:
#                ip  app  device   os  channel          click_time  \
# 163695487  179110    0       0   29      101 2017-11-06 16:01:42
# 169629803  198677    0       0   29      101 2017-11-06 16:01:42
# 169629804  198677    0       0   29      101 2017-11-06 16:02:46
# 148721816  128226    0       0   21      101 2017-11-06 16:12:51
# 150993835  136095    0       0   24      101 2017-11-06 16:14:22
# 150993836  136095    0       0   24      101 2017-11-06 16:14:38
# 150993837  136095    0       0   24      101 2017-11-06 16:18:54
# 152250485  139400    0       0  135      101 2017-11-06 16:20:43
# 148721817  128226    0       0   21      101 2017-11-06 16:42:39
# 35592590    31047    0       0   24      101 2017-11-06 16:45:45
# 163940761  179991    0       0   38      101 2017-11-06 17:00:06
# 161510415  172498    0       0  607      101 2017-11-06 17:03:15
# 161525429  172522    0       0  607      101 2017-11-06 17:03:15
# ...

# %%
train['time_diff'] = train.attributed_time - train.click_time
